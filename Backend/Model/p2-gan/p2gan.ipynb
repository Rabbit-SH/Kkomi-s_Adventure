# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Setup 🥱
# Read [paper](https://arxiv.org/abs/2001.07466) and visit [repo](https://github.com/i-evi/p2gan) for more details.

# %%
# PASCAL dataset
# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Out:
# ^C

# %%
# untar 
# !tar -xvf VOCtrainval_06-Nov-2007.tar
# Out:
# x VOCdevkit/
# x VOCdevkit/VOC2007/
# x VOCdevkit/VOC2007/Annotations/
# x VOCdevkit/VOC2007/Annotations/000005.xml
# x VOCdevkit/VOC2007/Annotations/000007.xml
# x VOCdevkit/VOC2007/Annotations/000009.xml
# x VOCdevkit/VOC2007/Annotations/000012.xml
# x VOCdevkit/VOC2007/Annotations/000016.xml
# x VOCdevkit/VOC2007/Annotations/000017.xml
# x VOCdevkit/VOC2007/Annotations/000019.xml
# x VOCdevkit/VOC2007/Annotations/000020.xml
# x VOCdevkit/VOC2007/Annotations/000021.xml
# x VOCdevkit/VOC2007/Annotations/000023.xml
# x VOCdevkit/VOC2007/Annotations/000024.xml
# x VOCdevkit/VOC2007/Annotations/000026.xml
# x VOCdevkit/VOC2007/Annotations/000030.xml
# x VOCdevkit/VOC2007/Annotations/000032.xml
# x VOCdevkit/VOC2007/Annotations/000033.xml
# x VOCdevkit/VOC2007/Annotations/000034.xml
# x VOCdevkit/VOC2007/Annotations/000035.xml
# x VOCdevkit/VOC2007/Annotations/000036.xml
# x VOCdevkit/VOC2007/Annotations/000039.xml
# x VOCdevkit/VOC2007/Annotations/000041.xml
# ...

# %%
# clone repo
# !git clone https://github.com/i-evi/p2gan.git
# Out:
# fatal: destination path 'p2gan' already exists and is not an empty directory.

# %%
# !pip install gdown

# %%
# !pip install opencv-python

# %%
import gdown

# VGG Weights
gdown.download('https://drive.google.com/uc?id=1abva-vfTJwJmBLMJWj5Eh6hMGGvM1U0A', output=None, quiet=False)
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1abva-vfTJwJmBLMJWj5Eh6hMGGvM1U0A
# From (redirected): https://drive.google.com/uc?id=1abva-vfTJwJmBLMJWj5Eh6hMGGvM1U0A&confirm=t&uuid=d3b7bbe8-875b-4399-92cf-1d2aef8118d7
# To: c:\Users\Administrator\Desktop\p_2gan\vgg16.npy
# 100%|██████████| 553M/553M [00:29<00:00, 18.9MB/s]
# 'vgg16.npy'

# %% [markdown]
# # Upload Images 🤳
# Upload at least one image to transfer style to. Optionally upload picture to train a new model on.

# %%
# # run as many times as need
# from google.colab import files
# files.upload()

# %%
# if you are training again, you can run this to remove previous model
#!rm -rf model_save

# %%
# store trained model here
# !mkdir model_save

# %%
# outputs will be stored here
# !mkdir output

# %% [markdown]
# # Train 🏃‍♀️
# Run this if you want to train a new model. You will see discriminator and generator performance at the end.

# %%
# !python train.py --model model_save --style ./style/style13.jpg --dataset ./VOCdevkit/VOC2007/JPEGImages/ --lambda 5e-6
# Out:
# c:\Users\Administrator\Desktop\p_2gan\vgg16.npy
# npy file loaded
# build model started
# c:\Users\Administrator\Desktop\p_2gan\vgg16.npy
# npy file loaded
# build model started
# epoch 0000 InnerProcess: 0/3
# epoch 0000 InnerProcess: 1/3
# epoch 0000 InnerProcess: 2/3
# Epoch 0 D_TURN D real =  0.55631185
# Epoch 0 D_TURN D fake =  0.5436542
# epoch 0001 InnerProcess: 0/3
# epoch 0001 InnerProcess: 1/3
# epoch 0001 InnerProcess: 2/3
# Epoch 1 D_TURN D real =  0.5749083
# Epoch 1 D_TURN D fake =  0.54098964
# epoch 0002 InnerProcess: 0/3
# epoch 0002 InnerProcess: 1/3
# epoch 0002 InnerProcess: 2/3
# Epoch 2 D_TURN D real =  0.5855915
# Epoch 2 D_TURN D fake =  0.53996384
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# ...

# %% [markdown]
# # Render 🧙‍♂️
# Run this to perform style transfer. There are several pretrained options from `available_models/`
# Visit the [repo](https://github.com/i-evi/p2gan) to see them.

# %%
# 이거 말고 밑에거 쓰는게 편함 파일 이름설정도 되고 (윈도우)
# !python render-keep-ratio.py --model model_good --inp ./content/21_thick.jpg --oup output --size 1024
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From c:\Users\Administrator\Desktop\p_2gan\model.py:58: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From render-keep-ratio.py:83: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From render-keep-ratio.py:85: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From render-keep-ratio.py:85: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
import subprocess
from PIL import Image

# 명령어 실행
command = 'python render-keep-ratio.py --model model_good --inp ./content/18.jpg --oup output --size 1024'
# command = 'python render-keep-ratio.py --model ./available_models/Qi-Baishi-FengYeHanChan/ --inp ./content/19.jpg --oup output --size 2048'
subprocess.run(command, shell=True)

# 이미지를 열어서 저장
result_image = Image.open('output/stylized.jpg')
# result_image.save('output2/stylized1_3_patch16.jpg')
result_image.save('output/stylized8_another.jpg')

# 결과물 이미지 표시 (선택 사항)
result_image.show()

# %% [markdown]
# # Download 👨‍🎨
# Download your image

# %%
from google.colab import files
files.download("output/stylized.jpg")
